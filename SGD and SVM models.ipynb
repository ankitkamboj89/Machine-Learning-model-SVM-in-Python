# %% [markdown]
# **Question 1 - Reading files and Inspecting columns**

# %% [markdown]
# **Data**: Consists of traning and testing data. The training set consists of 325 instances of multivariate remote sensing data of some forest in Japan. The training data consists of 28 columns. First column consists of class label, followed by data on 9 bands of spectrum. Last 18 columns consists of predicted minus observed value of every band. <br>
# <br>
# **Consistency**: The data seems to be consistent and there are no empty fields in the data.

# %%
import pandas as pd #using pandas to import and read the files.
train_data=pd.read_csv('training.csv') 
test_data=pd.read_csv('testing.csv')

# %%
train_data.head() #used to display first 5 rows of training data
# Out:
#   class  b1  b2  b3   b4  b5   b6   b7  b8  b9  ...  pred_minus_obs_H_b9  \
# 0     d  67  51  68  115  69  111  136  31  67  ...                -9.17
# 1     s  67  28  51   99  50   97   82  26  59  ...                -2.25
# 2     s  63  26  50   95  49   91   81  26  57  ...                -0.44
# 3     d  63  42  63   97  66  108  111  28  59  ...                -2.34
# 4     s  46  27  50   83  51   90   76  26  56  ...                 1.25
#
#    pred_minus_obs_S_b1  pred_minus_obs_S_b2  pred_minus_obs_S_b3  \
# 0               -18.27                -1.80                -6.32
# 1               -20.13                -2.11                -6.35
# 2               -17.64                -1.81                -4.70
# 3               -20.20                -1.89                -5.47
# 4               -18.62                -2.17                -7.11
#
#    pred_minus_obs_S_b4  pred_minus_obs_S_b5  pred_minus_obs_S_b6  \
# 0               -20.88                -1.63                -6.13
# ...

# %%
test_data.head() #used to display first 5 rows of testing data
# Out:
#   class  b1  b2  b3   b4  b5   b6   b7  b8  b9  ...  pred_minus_obs_H_b9  \
# 0     d  39  36  57   91  59  101   93  27  60  ...                -2.36
# 1     h  84  30  57  112  51   98   92  26  62  ...                -2.26
# 2     s  53  25  49   99  51   93   84  26  58  ...                -1.46
# 3     s  59  26  49  103  47   92   82  25  56  ...                 2.68
# 4     d  57  49  66  103  64  106  114  28  59  ...                -2.94
#
#    pred_minus_obs_S_b1  pred_minus_obs_S_b2  pred_minus_obs_S_b3  \
# 0               -18.41                -1.88                -6.43
# 1               -16.27                -1.95                -6.25
# 2               -15.92                -1.79                -4.64
# 3               -13.77                -2.53                -6.34
# 4               -21.74                -1.64                -4.62
#
#    pred_minus_obs_S_b4  pred_minus_obs_S_b5  pred_minus_obs_S_b6  \
# 0               -21.03                -1.60                -6.18
# ...

# %%
train_data.info() #checking data type and null data entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   class                325 non-null    object
#  1   b1                   325 non-null    int64
#  2   b2                   325 non-null    int64
#  3   b3                   325 non-null    int64
#  4   b4                   325 non-null    int64
#  5   b5                   325 non-null    int64
#  6   b6                   325 non-null    int64
#  7   b7                   325 non-null    int64
#  8   b8                   325 non-null    int64
#  9   b9                   325 non-null    int64
#  10  pred_minus_obs_H_b1  325 non-null    float64
#  11  pred_minus_obs_H_b2  325 non-null    float64
#  12  pred_minus_obs_H_b3  325 non-null    float64
#  13  pred_minus_obs_H_b4  325 non-null    float64
#  14  pred_minus_obs_H_b5  325 non-null    float64
# ...

# %%
test_data.info() #checking data type and null data entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   class                198 non-null    object
#  1   b1                   198 non-null    int64
#  2   b2                   198 non-null    int64
#  3   b3                   198 non-null    int64
#  4   b4                   198 non-null    int64
#  5   b5                   198 non-null    int64
#  6   b6                   198 non-null    int64
#  7   b7                   198 non-null    int64
#  8   b8                   198 non-null    int64
#  9   b9                   198 non-null    int64
#  10  pred_minus_obs_H_b1  198 non-null    float64
#  11  pred_minus_obs_H_b2  198 non-null    float64
#  12  pred_minus_obs_H_b3  198 non-null    float64
#  13  pred_minus_obs_H_b4  198 non-null    float64
#  14  pred_minus_obs_H_b5  198 non-null    float64
# ...

# %% [markdown]
# **Question 1 - Display different features**

# %% [markdown]
# **Scatter matrix of all features** - From the correlation matrix and the graphs of the features against each other it can be observed that feature (b2 & b3), (b5 & b6), and (b8 & b9) are highly correlated. <br>
# <br>
# **Individual specturm vs type of forest** <br>
# 1) It can be seen that the value of b1 band increase for 3 classes of forest d, s and h. hence this feature may had good correlation with the class label. <br>
# 2) It can be seen that the value of b2 band decreases for 3 classes of forest d, s and h. hence this feature may had good correlation with the class label. <br>
# 3) It can be seen that the value of b2 band decreases for 3 classes of forest d, s and h. hence this feature may had good correlation with the class label.

# %%
from pandas.plotting import scatter_matrix # method to check correlation between the attributes.
attributes = ["b1", "b2", "b3","b4", "b5" , "b6" , "b7" , "b8" , "b9" , "class"]
scatter_matrix(train_data[attributes], figsize=(12, 8))
import matplotlib.pyplot as plt
plt.title("Scatter Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
import seaborn
import matplotlib.pyplot as plt

seaborn.set(style = 'whitegrid')  
tip = seaborn.load_dataset("tips")  

seaborn.stripplot(y ='b1', x ='class', data = train_data, jitter = True, dodge = True)
plt.xlabel('Class')  #X-axis label
plt.ylabel('B1') #Y-axis label 
plt.title("Class vs B1 Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Class vs B1 Plot')

# %%
seaborn.stripplot(y ='b2', x ='class', data = train_data, jitter = True, dodge = True)
plt.xlabel('Class')  #X-axis label
plt.ylabel('B2') #Y-axis label 
plt.title("Class vs B2 Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Class vs B2 Plot')

# %%
seaborn.stripplot(y ='b3', x ='class', data = train_data, jitter = True, dodge = True)
plt.xlabel('Class')  #X-axis label
plt.ylabel('B3') #Y-axis label 
plt.title("Class vs B3 Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Class vs B3 Plot')

# %%
seaborn.stripplot(y ='b4', x ='class', data = train_data, jitter = True, dodge = True)
plt.xlabel('Class')  #X-axis label
plt.ylabel('B4') #Y-axis label 
plt.title("Class vs B4 Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Class vs B4 Plot')

# %%
seaborn.stripplot(y ='b5', x ='class', data = train_data, jitter = True, dodge = True)
plt.xlabel('Class')  #X-axis label
plt.ylabel('B5') #Y-axis label 
plt.title("Class vs B5 Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Class vs B5 Plot')

# %%
seaborn.stripplot(y ='b6', x ='class', data = train_data, jitter = True, dodge = True)
plt.xlabel('Class')  #X-axis label
plt.ylabel('B6') #Y-axis label 
plt.title("Class vs B6 Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Class vs B6 Plot')

# %%
seaborn.stripplot(y ='b7', x ='class', data = train_data, jitter = True, dodge = True)
plt.xlabel('Class')  #X-axis label
plt.ylabel('B7') #Y-axis label 
plt.title("Class vs B7 Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Class vs B7 Plot')

# %%
seaborn.stripplot(y ='b8', x ='class', data = train_data, jitter = True, dodge = True)
plt.xlabel('Class')  #X-axis label
plt.ylabel('B8') #Y-axis label 
plt.title("Class vs B8 Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Class vs B8 Plot')

# %%
seaborn.stripplot(y ='b9', x ='class', data = train_data, jitter = True, dodge = True)
plt.xlabel('Class')  #X-axis label
plt.ylabel('B9') #Y-axis label 
plt.title("Class vs B9 Plot") #Chart title.
# Out:
# Text(0.5, 1.0, 'Class vs B9 Plot')

# %% [markdown]
# **Question 2: Removing the columns with title "pred_minus_obs' from the data** <br>
# <br>
# The correlation matrix confirm the finding from the scatter plot. The specturm B2 & B3, B5 & B6 and B8 & B9 are **highly correlated**.

# %%
attribute=["pred_minus_obs_H_b1" ,"pred_minus_obs_H_b2", "pred_minus_obs_H_b3", "pred_minus_obs_H_b4", "pred_minus_obs_H_b5" , "pred_minus_obs_H_b6" , "pred_minus_obs_H_b7" , "pred_minus_obs_H_b8" , "pred_minus_obs_H_b9", "pred_minus_obs_S_b1" ,"pred_minus_obs_S_b2", "pred_minus_obs_S_b3", "pred_minus_obs_S_b4", "pred_minus_obs_S_b5" , "pred_minus_obs_S_b6" , "pred_minus_obs_S_b7" , "pred_minus_obs_S_b8" , "pred_minus_obs_S_b9"]
train_data_refined = train_data.drop(attribute, axis=1) 
test_data_refined = test_data.drop(attribute, axis=1)

# %%
train_data_refined.info() #information regarding new refined data after removing unwanted attributes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   325 non-null    object
#  1   b1      325 non-null    int64
#  2   b2      325 non-null    int64
#  3   b3      325 non-null    int64
#  4   b4      325 non-null    int64
#  5   b5      325 non-null    int64
#  6   b6      325 non-null    int64
#  7   b7      325 non-null    int64
#  8   b8      325 non-null    int64
#  9   b9      325 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 25.5+ KB

# %%
corr_matrix = train_data_refined.corr() #generating co-rrelation matrix among the attributes
corr_matrix
# Out:
#           b1        b2        b3        b4        b5        b6        b7  \
# b1  1.000000  0.193934  0.239083  0.659619  0.064797  0.125729  0.538652
# b2  0.193934  1.000000  0.973858  0.007348  0.856469  0.742261  0.371865
# b3  0.239083  0.973858  1.000000 -0.000216  0.811359  0.696819  0.302484
# b4  0.659619  0.007348 -0.000216  1.000000 -0.005669  0.239442  0.523521
# b5  0.064797  0.856469  0.811359 -0.005669  1.000000  0.916407  0.345639
# b6  0.125729  0.742261  0.696819  0.239442  0.916407  1.000000  0.371729
# b7  0.538652  0.371865  0.302484  0.523521  0.345639  0.371729  1.000000
# b8  0.221787  0.693000  0.687960  0.043042  0.773810  0.773242  0.268426
# b9  0.373938  0.639570  0.633026  0.206517  0.721207  0.769371  0.431312
#
#           b8        b9
# b1  0.221787  0.373938
# b2  0.693000  0.639570
# b3  0.687960  0.633026
# b4  0.043042  0.206517
# b5  0.773810  0.721207
# b6  0.773242  0.769371
# b7  0.268426  0.431312
# b8  1.000000  0.951385
# ...

# %% [markdown]
# **Question 3: Count the number of instances in each class**

# %% [markdown]
# The number of instances of each label class are shown in table below. But the data is **unbalanced**. This will be taken care by taking weighted average of each class as per their count in the data when calculating accuracy and F1 value.

# %%
train_data_refined['class'].value_counts() #checking balanaced or un-balanced data in train data
# Out:
# s    136
# d    105
# o     46
# h     38
# Name: class, dtype: int64

# %% [markdown]
# There are four types of forest labels in the first column "class"

# %%
test_data_refined["class"].value_counts() #checking balanaced or un-balanced data in test data
# Out:
# s    59
# d    54
# h    48
# o    37
# Name: class, dtype: int64

# %% [markdown]
# The proportion of each class in the data

# %%
(train_data_refined["class"].value_counts())/len(train_data_refined) #checking proportion of each class in train data
# Out:
# s    0.418462
# d    0.323077
# o    0.141538
# h    0.116923
# Name: class, dtype: float64

# %%
(test_data_refined["class"].value_counts())/len(test_data_refined) #checking proportion of each class in test data
# Out:
# s    0.297980
# d    0.272727
# h    0.242424
# o    0.186869
# Name: class, dtype: float64

# %% [markdown]
# **The proportion of different classes is also not uniform across train and test data.**

# %% [markdown]
# Refining the data below, separating the label and explanatory variable columns in two different dataframes

# %%
train_data_refined_lables = train_data_refined["class"].copy() #separating the data: attributes from labels
train_data_refined = train_data_refined.drop("class", axis=1) 

test_data_refined_lables = test_data_refined["class"].copy() 
test_data_refined = test_data_refined.drop("class", axis=1)

# %% [markdown]
# **Question 4: Standard scaler applied on the data to scale the features on both train and Test data (separately)**

# %%
from sklearn.pipeline import Pipeline #applying standscaler to scale the attributes
from sklearn.preprocessing import StandardScaler

std_pipeline = Pipeline([
        ('std_scaler', StandardScaler()),
    ])

train_data_refined_tr = std_pipeline.fit_transform(train_data_refined)

# %%
test_data_refined_tr = std_pipeline.fit_transform(test_data_refined) #scaling the attributes in test data spearately from the train data usinf same scaler as on train data

# %% [markdown]
# **Question 5: Fitting the support vector machine classifier**

# %% [markdown]
# **Hyperparameters** : <br>
# 1) kernels: ['rbf', 'poly'] <br>
# 2) gamma: [.1,2,5] <br>
# 3) C = [.1,1,100,1000] <br>
# 4) degree:[1,2,3,4,5,6] <br>
# 5) Cross-validations: 3 <br>
# <br>
# **Model Selection**: <br>
# 1) for kernel 'rbf', accuracy of model is 84% on train data, which is less than 89% accuracy of kernel 'poly'. <br>
# 2) cross validation score on test data of kernel 'poly' (32%) is lot better than kernel 'rbf' (88%). <br>
# <br>
# So we select SVM classifier with hyperparameter: 'C': 100, 'degree': 1, 'kernel': 'poly' for futher comparision with SGD classifier.

# %%
from sklearn.model_selection import GridSearchCV #training the SVM model for only 'rbf' kernel using grid search and 3 fold cross validation
from sklearn import svm
param_grid={'C':[0.1,1,100,1000], 'kernel' :['rbf'],'gamma':[.1,2,5]}
grid=GridSearchCV(svm.SVC(), param_grid, cv=3, scoring='accuracy')
grid.fit(train_data_refined_tr, train_data_refined_lables)
# Out:
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 100, 1000], 'gamma': [0.1, 2, 5],
#                          'kernel': ['rbf']},
#              scoring='accuracy')

# %%
print(grid.best_params_) #getting model with best hyper parameters out of models with 'rbf' kernel
print(grid.score(test_data_refined_tr, test_data_refined_lables))
# Out:
# {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.8434343434343434

# %%
from sklearn.model_selection import GridSearchCV #training the SVM model for only 'poly' kernel using grid search and 3 fold cross validation
param_grid={'C':[0.1,1,100,1000], 'kernel' :['poly'],'degree':[1,2,3,4,5,6]}
grid=GridSearchCV(svm.SVC(), param_grid, cv=3)
grid.fit(train_data_refined_tr, train_data_refined_lables)
# Out:
# GridSearchCV(cv=3, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 100, 1000], 'degree': [1, 2, 3, 4, 5, 6],
#                          'kernel': ['poly']})

# %%
print(grid.best_params_) #getting model with best hyper parameters out of models with 'poly' kernel
print(grid.score(test_data_refined_tr, test_data_refined_lables))
# Out:
# {'C': 100, 'degree': 1, 'kernel': 'poly'}
# 0.8888888888888888

# %%
from sklearn.model_selection import cross_val_score #checking cross validation score for 'rbf' kernel models
svc_rbf=svm.SVC(kernel='rbf',C=1, gamma=.1)
svc_rbf.fit(train_data_refined_tr, train_data_refined_lables)
print('Accuracy on test data is:', cross_val_score(svc_rbf,test_data_refined, test_data_refined_lables,cv=3))
print('Accuracy on train data is:', cross_val_score(svc_rbf, train_data_refined_tr, train_data_refined_lables,cv=3))
# Out:
# Accuracy on test data is: [0.36363636 0.31818182 0.31818182]
# Accuracy on train data is: [0.85321101 0.92592593 0.88888889]

# %%
svc_poly1=svm.SVC(kernel='poly',C=100, degree=1) #checking cross validation score for 'poly' kernel models
svc_poly1.fit(train_data_refined_tr, train_data_refined_lables)
print('Accuracy on test data is:', cross_val_score(svc_poly1,test_data_refined, test_data_refined_lables,cv=3))
print('Accuracy on train data is:', cross_val_score(svc_poly1, train_data_refined_tr, train_data_refined_lables,cv=3))
# Out:
# Accuracy on test data is: [0.87878788 0.93939394 0.96969697]
# Accuracy on train data is: [0.89908257 0.90740741 0.84259259]

# %% [markdown]
# **Q6: Stochastic Gradient Descent Classifier**

# %% [markdown]
# **Hyperparameters** : <br>
# 1) 'loss' : ['hinge', 'log', 'modified_huber', 'squared_hinge','perceptron'], <br>
# 2) 'penalty' : ['l1', 'l2', 'elasticnet'] <br>
# <br>
# **Model Selection**: <br>
# 1) SGD model with hyperparameters 'loss': 'squared_hinge', 'penalty': 'elasticnet' with accuracy of 84% on train data.

# %%
from sklearn.linear_model import SGDClassifier #training the SGD model
sgd_clf=SGDClassifier(random_state=42)
sgd_clf.fit(train_data_refined_tr, train_data_refined_lables)
# Out:
# SGDClassifier(random_state=42)

# %%
from sklearn.model_selection import GridSearchCV #using Grid search to find the best model with loss and penality os hyper parameters
param_grid={'loss' : ['hinge', 'log', 'modified_huber', 'squared_hinge','perceptron'], 'penalty' : ['l1', 'l2', 'elasticnet']}
sgd = SGDClassifier(loss="hinge", penalty="l2",random_state=41) 
SGD_Grid = GridSearchCV(sgd, param_grid, cv=3)

# %%
SGD_Grid_model = SGD_Grid.fit(train_data_refined_tr, train_data_refined_lables)

# %%
print('Best Score: ', SGD_Grid_model.best_score_) #getting the best model from grid search
print('Best Params: ', SGD_Grid_model.best_params_)
# Out:
# Best Score:  0.849388379204893
# Best Params:  {'loss': 'squared_hinge', 'penalty': 'elasticnet'}

# %%
from sklearn.model_selection import cross_val_score #checking the accuracy using croos fold score
sgd = SGDClassifier(loss='hinge', penalty='l2',random_state=41) 
sgd_model=sgd.fit(train_data_refined_tr, train_data_refined_lables)
print('Accuracy on test data is:', cross_val_score(sgd_model,test_data_refined, test_data_refined_lables,cv=3))
print('Accuracy on train data is:', cross_val_score(sgd_model, train_data_refined_tr, train_data_refined_lables,cv=3))
# Out:
# Accuracy on test data is: [0.86363636 0.87878788 0.89393939]
# Accuracy on train data is: [0.78899083 0.86111111 0.81481481]

# %% [markdown]
# **Question 7 Comparing both the models:**

# %% [markdown]
# calculating: <br>
# 1) confusion matrix <br>
# 2) precision, <br>
# 3) recall, <br>
# 4) f1 Score <br>
# 5) and Accuracy <br>
# for both SVM and SGD Classifier <br>
# <br>
# As the data is baised, we calculate the precison, recall and F1 Score using weighted average to compensate for not having balanced distribution of class in the data.

# %% [markdown]
# **SVM model**

# %%
svc_test_data_predicted_labels=svc_poly1.predict(test_data_refined_tr) #calculating the prediction values for the instances

# %%
from sklearn.metrics import confusion_matrix #confusion matrix for the SVM model
confusion_matrix(test_data_refined_lables,svc_test_data_predicted_labels)
# Out:
# array([[53,  0,  1,  0],
#        [ 0, 33,  0, 15],
#        [ 4,  0, 33,  0],
#        [ 0,  1,  1, 57]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score #getting precision, recall and F1 score for SVM classifier
SVC_Precision = precision_score(test_data_refined_lables, svc_test_data_predicted_labels,average='weighted')
SVC_recall=recall_score(test_data_refined_lables, svc_test_data_predicted_labels, average='weighted')
SVC_f1=f1_score(test_data_refined_lables, svc_test_data_predicted_labels,average='weighted')
SVC_Precision
# Out:
# 0.9009737839846198

# %%
SVC_recall
# Out:
# 0.8888888888888888

# %%
SVC_f1
# Out:
# 0.8861711718488856

# %%
from sklearn.metrics import accuracy_score #Accuracy score for SVM model
AccuracyScore = accuracy_score(test_data_refined_lables,svc_test_data_predicted_labels)
AccuracyScore
# Out:
# 0.8888888888888888

# %% [markdown]
# **SGD model**

# %%
SGD_test_data_predicted_labels=sgd.predict(test_data_refined_tr) #calculating the prediction values for the instances

# %%
from sklearn.metrics import confusion_matrix #calculating the confusion matrix for SGD model
confusion_matrix(test_data_refined_lables,SGD_test_data_predicted_labels)
# Out:
# array([[53,  0,  1,  0],
#        [ 1, 36,  0, 11],
#        [ 1,  0, 35,  1],
#        [ 0,  1,  1, 57]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score #getting precision, recall and F1 score for SGD classifier
SGD_Precision = precision_score(test_data_refined_lables,SGD_test_data_predicted_labels, average='weighted')
SGD_recall=recall_score(test_data_refined_lables,SGD_test_data_predicted_labels, average='weighted')
SGD_f1=f1_score(test_data_refined_lables,SGD_test_data_predicted_labels, average='weighted')
SGD_Precision
# Out:
# 0.9216070544133784

# %%
SGD_recall
# Out:
# 0.9141414141414141

# %%
SGD_f1
# Out:
# 0.9127245454409175

# %%
from sklearn.metrics import accuracy_score #accuracy score for the SGD model
AccuracyScore = accuracy_score(test_data_refined_lables,SGD_test_data_predicted_labels)
AccuracyScore
# Out:
# 0.9141414141414141

# %% [markdown]
#  Both Accuracy and F1 score of SGD classifier is better than SVM classifier.
#
# **Therefore we select SGD classifier.**
